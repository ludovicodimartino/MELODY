# %% [markdown]
# ## Populate an RDF database
#
# This notebook reports the main steps to download CSV files, process them and create an RDF dataset from them accordingly to an ontology.
#
# To measure execution time in Jupyter notebooks: <code>pip install ipython-autotime</code>

# %%
# required libraries
import pandas as pd
import os
import ast
import unicodedata
import re
from pathlib import Path

# %%
# parameters and URLs
path = str(Path(os.path.abspath(os.getcwd())).parent.absolute())
grammyCategoriesUrl = path + '/ProvaPython/GrammyCategories.csv'


# saving folder
savePath =  path + '/ProvaPython/rdf/'

# %% [markdown]
# ## Grammy

# %%
# Load the CSV files in memory
categories = pd.read_csv(grammyCategoriesUrl, sep=',')

print(categories)

# Converte la colonna 'Sub Genres' da stringa a una lista Python
categories['Sub Genres'] = categories['Sub Genres'].apply(ast.literal_eval)

print(categories.head())

# Verifica i tipi di dati del DataFrame
print(categories.dtypes)
# Out:
#                                           Macro Genre  \
# 0                              Pop & Dance/Electronic
# 1                           Rock, Metal & Alternative
# 2                       R&B, Rap & Spoken Word Poetry
# 3   Jazz, Traditional Pop, Contemporary Instrument...
# 4                            Country & American Roots
# 5                     Gospel & Contemporary Christian
# 6   Latin, Global, Reggae & New Age, Ambient or Chant
# 7   Children's, Comedy, Audio Books, Visual Media ...
# 8                         Package, Notes & Historical
# 9   Production, Engineering, Composition & Arrange...
# 10                                          Classical
#
#                                            Sub Genres
# 0   ['Best Pop Solo Performance', 'Best Pop Duo/Gr...
# 1   ['Best Rock Performance', 'Best Metal Performa...
# 2   ['Best R&B Performance', 'Best Traditional R&B...
# 3   ['Best Jazz Performance', 'Best Jazz Vocal Alb...
# 4   ['Best Country Solo Performance', 'Best Countr...
# 5   ['Best Gospel Performance/Song', 'Best Contemp...
# 6   ['Best Latin Pop Album', 'Best Música Urbana A...
# 7   ["Best Children's Music Album", 'Best Comedy A...
# 8   ['Best Recording Package', 'Best Boxed or Spec...
# 9   ['Best Engineered Album, Non-Classical', 'Best...
# 10  ['Best Orchestral Performance', 'Best Opera Re...
#                                          Macro Genre  \
# 0                             Pop & Dance/Electronic
# 1                          Rock, Metal & Alternative
# 2                      R&B, Rap & Spoken Word Poetry
# 3  Jazz, Traditional Pop, Contemporary Instrument...
# 4                           Country & American Roots
#
#                                           Sub Genres
# 0  [Best Pop Solo Performance, Best Pop Duo/Group...
# 1  [Best Rock Performance, Best Metal Performance...
# 2  [Best R&B Performance, Best Traditional R&B Pe...
# 3  [Best Jazz Performance, Best Jazz Vocal Album,...
# 4  [Best Country Solo Performance, Best Country D...
# Macro Genre    object
# Sub Genres     object
# dtype: object

# %%
def normalize_uri(name):
    # Rimuove accenti e caratteri speciali
    name = unicodedata.normalize('NFKD', name).encode('ASCII', 'ignore').decode('ASCII')
    name = name.replace(" ", "-")
    name = name.replace(",", "").replace("'", "")
    return name

# %% [markdown]
# We need to install <code>RDFLib</code>
#
# <code>pip3 install rdflib </code> [Documentation](https://rdflib.readthedocs.io/en/stable/gettingstarted.html)

# %%
# Load the required libraries
from rdflib import Graph, Literal, RDF, URIRef, Namespace
# rdflib knows about some namespaces, like FOAF
from rdflib.namespace import FOAF, XSD, SKOS, RDFS

# %%
# Construct the country and the movie ontology namespaces not known by RDFlib
ME = Namespace("http://www.dei.unipd.it/~gdb/ontology/melody#")

#create the graph
g = Graph()

# Bind the namespaces to a prefix for more readable output
g.bind("xsd", XSD)
g.bind("mel", ME)
g.bind("skos", SKOS)
g.bind("rdfs", RDFS)

# %%
SCHEME_URI = URIRef(ME.GrammyCategorySchema)
#  individuo GrammyCategorySchema type ConceptScheme
g.add((SCHEME_URI, RDF.type, SKOS.ConceptScheme))


for _, row in categories.iterrows():
    macro_genre = row['Macro Genre']
    sub_genres = row['Sub Genres']

    # URI del macrogenere
    macro_genre_uri = URIRef(ME + normalize_uri(macro_genre))
    print(f"Macro Genre URI: {macro_genre_uri}")
    
    # Aggiungi il macrogenere come SKOS Concept
    g.add((macro_genre_uri, RDF.type, SKOS.Concept))
    g.add((macro_genre_uri, RDF.type, ME.GrammyCategory))
    g.add((macro_genre_uri, RDFS.label, Literal(macro_genre, lang="en")))
    g.add((macro_genre_uri, SKOS.inScheme, SCHEME_URI))
    

    # Aggiungi ciascun sottogenere come SKOS Concept e GrammyCategory
    for sub_genre in sub_genres:
        sub_genre_uri = URIRef(ME + normalize_uri(sub_genre))
        print(f"Sub-Genre URI: {sub_genre_uri}")
        g.add((sub_genre_uri, RDF.type, SKOS.Concept))
        g.add((sub_genre_uri, RDF.type, URIRef(ME.GrammyCategory)))
        g.add((sub_genre_uri, RDFS.label, Literal(sub_genre, lang="en")))
        g.add((sub_genre_uri, SKOS.broader, macro_genre_uri))
# Out:
# Macro Genre URI: http://www.dei.unipd.it/~gdb/ontology/melody#Pop-&-Dance/Electronic
# Sub-Genre URI: http://www.dei.unipd.it/~gdb/ontology/melody#Best-Pop-Solo-Performance
# Sub-Genre URI: http://www.dei.unipd.it/~gdb/ontology/melody#Best-Pop-Duo/Group-Performance
# Sub-Genre URI: http://www.dei.unipd.it/~gdb/ontology/melody#Best-Pop-Vocal-Album
# Sub-Genre URI: http://www.dei.unipd.it/~gdb/ontology/melody#Best-Dance/Electronic-Recording
# Sub-Genre URI: http://www.dei.unipd.it/~gdb/ontology/melody#Best-Dance-Pop-Recording
# Sub-Genre URI: http://www.dei.unipd.it/~gdb/ontology/melody#Best-Dance/Electronic-Album
# Sub-Genre URI: http://www.dei.unipd.it/~gdb/ontology/melody#Best-Remixed-Recording
# Sub-Genre URI: http://www.dei.unipd.it/~gdb/ontology/melody#Best-Female-Pop-Vocal-Performance
# Sub-Genre URI: http://www.dei.unipd.it/~gdb/ontology/melody#Best-Male-Pop-Vocal-Performance
# Sub-Genre URI: http://www.dei.unipd.it/~gdb/ontology/melody#Best-Pop-Performance-by-a-Duo-or-Group-with-Vocals
# Sub-Genre URI: http://www.dei.unipd.it/~gdb/ontology/melody#Best-Pop-Collaboration-with-Vocals
# Sub-Genre URI: http://www.dei.unipd.it/~gdb/ontology/melody#Best-Pop-Instrumental-Performance
# Sub-Genre URI: http://www.dei.unipd.it/~gdb/ontology/melody#Best-Pop-Instrumental-Performance-by-an-Arranger-Composer-Orchestra-and/or-Choral-Leader
# Sub-Genre URI: http://www.dei.unipd.it/~gdb/ontology/melody#Best-Performance-by-a-Vocal-Group
# Sub-Genre URI: http://www.dei.unipd.it/~gdb/ontology/melody#Best-Performance-by-a-Chorus
# Sub-Genre URI: http://www.dei.unipd.it/~gdb/ontology/melody#Best-Instrumental-Performance
# Sub-Genre URI: http://www.dei.unipd.it/~gdb/ontology/melody#Best-Performance-by-an-Orchestra--for-Dancing
# Sub-Genre URI: http://www.dei.unipd.it/~gdb/ontology/melody#Best-Performance-by-an-Orchestra-or-Instrumentalist-with-Orchestra
# Sub-Genre URI: http://www.dei.unipd.it/~gdb/ontology/melody#Best-Contemporary-Performance
# Sub-Genre URI: http://www.dei.unipd.it/~gdb/ontology/melody#Best-Contemporary-Performance-by-a-Chorus
# Sub-Genre URI: http://www.dei.unipd.it/~gdb/ontology/melody#Best-Contemporary-Song
# Sub-Genre URI: http://www.dei.unipd.it/~gdb/ontology/melody#Best-Disco-Recording
# Macro Genre URI: http://www.dei.unipd.it/~gdb/ontology/melody#Rock-Metal-&-Alternative
# Sub-Genre URI: http://www.dei.unipd.it/~gdb/ontology/melody#Best-Rock-Performance
# Sub-Genre URI: http://www.dei.unipd.it/~gdb/ontology/melody#Best-Metal-Performance
# Sub-Genre URI: http://www.dei.unipd.it/~gdb/ontology/melody#Best-Rock-Song
# Sub-Genre URI: http://www.dei.unipd.it/~gdb/ontology/melody#Best-Rock-Album
# Sub-Genre URI: http://www.dei.unipd.it/~gdb/ontology/melody#Best-Alternative-Music-Performance
# Sub-Genre URI: http://www.dei.unipd.it/~gdb/ontology/melody#Best-Alternative-Music-Album
# Sub-Genre URI: http://www.dei.unipd.it/~gdb/ontology/melody#Best-Female-Rock-Vocal-Performance
# Sub-Genre URI: http://www.dei.unipd.it/~gdb/ontology/melody#Best-Male-Rock-Vocal-Performance
# Sub-Genre URI: http://www.dei.unipd.it/~gdb/ontology/melody#Best-Rock-Solo-Vocal-Performance
# Sub-Genre URI: http://www.dei.unipd.it/~gdb/ontology/melody#Best-Rock-Performance-by-a-Duo-or-Group-with-Vocal
# Sub-Genre URI: http://www.dei.unipd.it/~gdb/ontology/melody#Best-Rock-Instrumental-Performance
# Sub-Genre URI: http://www.dei.unipd.it/~gdb/ontology/melody#Best-Hard-Rock/Metal-Performance-Vocal-or-Instrumental
# Sub-Genre URI: http://www.dei.unipd.it/~gdb/ontology/melody#Best-Hard-Rock-Performance
# Sub-Genre URI: http://www.dei.unipd.it/~gdb/ontology/melody#Best-Hard-Rock/Metal-Performance
# Macro Genre URI: http://www.dei.unipd.it/~gdb/ontology/melody#R&B-Rap-&-Spoken-Word-Poetry
# Sub-Genre URI: http://www.dei.unipd.it/~gdb/ontology/melody#Best-R&B-Performance
# Sub-Genre URI: http://www.dei.unipd.it/~gdb/ontology/melody#Best-Traditional-R&B-Performance
# Sub-Genre URI: http://www.dei.unipd.it/~gdb/ontology/melody#Best-R&B-Song
# Sub-Genre URI: http://www.dei.unipd.it/~gdb/ontology/melody#Best-Progressive-R&B-Album
# Sub-Genre URI: http://www.dei.unipd.it/~gdb/ontology/melody#Best-R&B-Album
# Sub-Genre URI: http://www.dei.unipd.it/~gdb/ontology/melody#Best-Rap-Performance
# Sub-Genre URI: http://www.dei.unipd.it/~gdb/ontology/melody#Best-Melodic-Rap-Performance
# Sub-Genre URI: http://www.dei.unipd.it/~gdb/ontology/melody#Best-Rap-Song
# Sub-Genre URI: http://www.dei.unipd.it/~gdb/ontology/melody#Best-Rap-Album
# Sub-Genre URI: http://www.dei.unipd.it/~gdb/ontology/melody#Best-Spoken-Word-Poetry-Album
# Sub-Genre URI: http://www.dei.unipd.it/~gdb/ontology/melody#Best-Urban/Alternative-Performance
# Sub-Genre URI: http://www.dei.unipd.it/~gdb/ontology/melody#Best-Female-R&B-Vocal-Performance
# Sub-Genre URI: http://www.dei.unipd.it/~gdb/ontology/melody#Best-Male-R&B-Vocal-Performance
# Sub-Genre URI: http://www.dei.unipd.it/~gdb/ontology/melody#Best-R&B-Performance-by-a-Duo-or-Group-with-Vocals
# Sub-Genre URI: http://www.dei.unipd.it/~gdb/ontology/melody#Best-Contemporary-R&B-Album
# Sub-Genre URI: http://www.dei.unipd.it/~gdb/ontology/melody#Best-R&B-Solo-Vocal-Performance-Male-or-Female
# Sub-Genre URI: http://www.dei.unipd.it/~gdb/ontology/melody#Best-R&B-Instrumental-Performance
# Sub-Genre URI: http://www.dei.unipd.it/~gdb/ontology/melody#Best-Rap-Solo-Performance
# Sub-Genre URI: http://www.dei.unipd.it/~gdb/ontology/melody#Best-Rap-Performance-by-a-Duo-or-Group
# Sub-Genre URI: http://www.dei.unipd.it/~gdb/ontology/melody#Best-Female-Rap-Solo-Performance
# Sub-Genre URI: http://www.dei.unipd.it/~gdb/ontology/melody#Best-Male-Rap-Solo-Performance
# Macro Genre URI: http://www.dei.unipd.it/~gdb/ontology/melody#Jazz-Traditional-Pop-Contemporary-Instrumental-&-Musical-Theater
# Sub-Genre URI: http://www.dei.unipd.it/~gdb/ontology/melody#Best-Jazz-Performance
# Sub-Genre URI: http://www.dei.unipd.it/~gdb/ontology/melody#Best-Jazz-Vocal-Album
# Sub-Genre URI: http://www.dei.unipd.it/~gdb/ontology/melody#Best-Jazz-Instrumental-Album
# Sub-Genre URI: http://www.dei.unipd.it/~gdb/ontology/melody#Best-Large-Jazz-Ensemble-Album
# Sub-Genre URI: http://www.dei.unipd.it/~gdb/ontology/melody#Best-Latin-Jazz-Album
# Sub-Genre URI: http://www.dei.unipd.it/~gdb/ontology/melody#Best-Alternative-Jazz-Album
# Sub-Genre URI: http://www.dei.unipd.it/~gdb/ontology/melody#Best-Traditional-Pop-Vocal-Album
# Sub-Genre URI: http://www.dei.unipd.it/~gdb/ontology/melody#Best-Contemporary-Instrumental-Album
# Sub-Genre URI: http://www.dei.unipd.it/~gdb/ontology/melody#Best-Musical-Theater-Album
# Sub-Genre URI: http://www.dei.unipd.it/~gdb/ontology/melody#Best-Jazz-Fusion-Performance
# Sub-Genre URI: http://www.dei.unipd.it/~gdb/ontology/melody#Best-Jazz-Vocal-Performance-Female
# Sub-Genre URI: http://www.dei.unipd.it/~gdb/ontology/melody#Best-Jazz-Vocal-Performance-Male
# Sub-Genre URI: http://www.dei.unipd.it/~gdb/ontology/melody#Best-Jazz-Vocal-Performance-Duo-or-Group
# Sub-Genre URI: http://www.dei.unipd.it/~gdb/ontology/melody#Best-Original-Jazz-Composition
# Sub-Genre URI: http://www.dei.unipd.it/~gdb/ontology/melody#Best-Contemporary-Jazz-Album
# Sub-Genre URI: http://www.dei.unipd.it/~gdb/ontology/melody#Best-Ethnic-or-Traditional-Folk-Recording
# Sub-Genre URI: http://www.dei.unipd.it/~gdb/ontology/melody#Best-Polka-Album
# Macro Genre URI: http://www.dei.unipd.it/~gdb/ontology/melody#Country-&-American-Roots
# Sub-Genre URI: http://www.dei.unipd.it/~gdb/ontology/melody#Best-Country-Solo-Performance
# Sub-Genre URI: http://www.dei.unipd.it/~gdb/ontology/melody#Best-Country-Duo/Group-Performance
# Sub-Genre URI: http://www.dei.unipd.it/~gdb/ontology/melody#Best-Country-Song
# Sub-Genre URI: http://www.dei.unipd.it/~gdb/ontology/melody#Best-Country-Album
# Sub-Genre URI: http://www.dei.unipd.it/~gdb/ontology/melody#Best-American-Roots-Performance
# Sub-Genre URI: http://www.dei.unipd.it/~gdb/ontology/melody#Best-Americana-Performance
# Sub-Genre URI: http://www.dei.unipd.it/~gdb/ontology/melody#Best-American-Roots-Song
# Sub-Genre URI: http://www.dei.unipd.it/~gdb/ontology/melody#Best-Americana-Album
# Sub-Genre URI: http://www.dei.unipd.it/~gdb/ontology/melody#Best-Bluegrass-Album
# Sub-Genre URI: http://www.dei.unipd.it/~gdb/ontology/melody#Best-Traditional-Blues-Album
# Sub-Genre URI: http://www.dei.unipd.it/~gdb/ontology/melody#Best-Contemporary-Blues-Album
# Sub-Genre URI: http://www.dei.unipd.it/~gdb/ontology/melody#Best-Folk-Album
# Sub-Genre URI: http://www.dei.unipd.it/~gdb/ontology/melody#Best-Regional-Roots-Music-Album
# Sub-Genre URI: http://www.dei.unipd.it/~gdb/ontology/melody#Best-Female-Country-Vocal-Performance
# Sub-Genre URI: http://www.dei.unipd.it/~gdb/ontology/melody#Best-Male-Country-Vocal-Performance
# Sub-Genre URI: http://www.dei.unipd.it/~gdb/ontology/melody#Best-Country-Performance-by-a-Duo-or-Group-with-Vocals
# Sub-Genre URI: http://www.dei.unipd.it/~gdb/ontology/melody#Best-Country-Collaboration-with-Vocals
# Sub-Genre URI: http://www.dei.unipd.it/~gdb/ontology/melody#Best-Country-Instrumental-Performance
# Sub-Genre URI: http://www.dei.unipd.it/~gdb/ontology/melody#Best-Country-&-Western-Recording
# Sub-Genre URI: http://www.dei.unipd.it/~gdb/ontology/melody#Best-New-Country-&-Western-Artist
# Macro Genre URI: http://www.dei.unipd.it/~gdb/ontology/melody#Gospel-&-Contemporary-Christian
# Sub-Genre URI: http://www.dei.unipd.it/~gdb/ontology/melody#Best-Gospel-Performance/Song
# Sub-Genre URI: http://www.dei.unipd.it/~gdb/ontology/melody#Best-Contemporary-Christian-Music-Performance/Song
# Sub-Genre URI: http://www.dei.unipd.it/~gdb/ontology/melody#Best-Gospel-Album
# Sub-Genre URI: http://www.dei.unipd.it/~gdb/ontology/melody#Best-Contemporary-Christian-Music-Album
# Sub-Genre URI: http://www.dei.unipd.it/~gdb/ontology/melody#Best-Roots-Gospel-Album
# Sub-Genre URI: http://www.dei.unipd.it/~gdb/ontology/melody#Best-Pop/Contemporary-Gospel-Album
# Sub-Genre URI: http://www.dei.unipd.it/~gdb/ontology/melody#Best-Rock-Gospel-Album
# Sub-Genre URI: http://www.dei.unipd.it/~gdb/ontology/melody#Best-Traditional-Gospel-Album
# Sub-Genre URI: http://www.dei.unipd.it/~gdb/ontology/melody#Best-Contemporary-R&B-Gospel-Album
# Sub-Genre URI: http://www.dei.unipd.it/~gdb/ontology/melody#Best-Contemporary-Christian-Music-Song
# Sub-Genre URI: http://www.dei.unipd.it/~gdb/ontology/melody#Best-Gospel/Contemporary-Christian-Music-Performance
# Sub-Genre URI: http://www.dei.unipd.it/~gdb/ontology/melody#Best-Gospel-Choir-or-Chorus-Album
# Sub-Genre URI: http://www.dei.unipd.it/~gdb/ontology/melody#Best-Gospel-Performance-Traditional
# Sub-Genre URI: http://www.dei.unipd.it/~gdb/ontology/melody#Best-Gospel-Performance-Contemporary
# Sub-Genre URI: http://www.dei.unipd.it/~gdb/ontology/melody#Best-Gospel-Song
# Sub-Genre URI: http://www.dei.unipd.it/~gdb/ontology/melody#Best-Gospel-Vocal-Performance-Female
# Sub-Genre URI: http://www.dei.unipd.it/~gdb/ontology/melody#Best-Gospel-Vocal-Performance-Male
# Sub-Genre URI: http://www.dei.unipd.it/~gdb/ontology/melody#Best-Gospel-Vocal-Performance-by-a-Duo-or-Group-Choir-or-Chorus
# Sub-Genre URI: http://www.dei.unipd.it/~gdb/ontology/melody#Best-Soul-Gospel-Performance
# Sub-Genre URI: http://www.dei.unipd.it/~gdb/ontology/melody#Best-Soul-Gospel-Performance-Traditional
# Sub-Genre URI: http://www.dei.unipd.it/~gdb/ontology/melody#Best-Soul-Gospel-Performance-Contemporary
# Sub-Genre URI: http://www.dei.unipd.it/~gdb/ontology/melody#Best-Soul-Gospel-Performance-Female
# Sub-Genre URI: http://www.dei.unipd.it/~gdb/ontology/melody#Best-Soul-Gospel-Performance-Male
# Sub-Genre URI: http://www.dei.unipd.it/~gdb/ontology/melody#Best-Soul-Gospel-Performance-Male-or-Female
# Sub-Genre URI: http://www.dei.unipd.it/~gdb/ontology/melody#Best-Soul-Gospel-Performance-by-a-Duo-or-Group-Choir-or-Chorus
# Sub-Genre URI: http://www.dei.unipd.it/~gdb/ontology/melody#Best-Southern-Country-or-Bluegrass-Gospel-Album
# Sub-Genre URI: http://www.dei.unipd.it/~gdb/ontology/melody#Best-Inspirational-Performance
# Macro Genre URI: http://www.dei.unipd.it/~gdb/ontology/melody#Latin-Global-Reggae-&-New-Age-Ambient-or-Chant
# Sub-Genre URI: http://www.dei.unipd.it/~gdb/ontology/melody#Best-Latin-Pop-Album
# Sub-Genre URI: http://www.dei.unipd.it/~gdb/ontology/melody#Best-Musica-Urbana-Album
# Sub-Genre URI: http://www.dei.unipd.it/~gdb/ontology/melody#Best-Latin-Rock-or-Alternative-Album
# Sub-Genre URI: http://www.dei.unipd.it/~gdb/ontology/melody#Best-Musica-Mexicana-Album
# Sub-Genre URI: http://www.dei.unipd.it/~gdb/ontology/melody#Best-Tropical-Latin-Album
# Sub-Genre URI: http://www.dei.unipd.it/~gdb/ontology/melody#Best-Global-Music-Performance
# Sub-Genre URI: http://www.dei.unipd.it/~gdb/ontology/melody#Best-African-Music-Performance
# Sub-Genre URI: http://www.dei.unipd.it/~gdb/ontology/melody#Best-Global-Music-Album
# Sub-Genre URI: http://www.dei.unipd.it/~gdb/ontology/melody#Best-Reggae-Album
# Sub-Genre URI: http://www.dei.unipd.it/~gdb/ontology/melody#Best-New-Age-Ambient-Or-Chant-Album
# Sub-Genre URI: http://www.dei.unipd.it/~gdb/ontology/melody#Best-Blues-Album
# Sub-Genre URI: http://www.dei.unipd.it/~gdb/ontology/melody#Best-Traditional-Folk-Album
# Sub-Genre URI: http://www.dei.unipd.it/~gdb/ontology/melody#Best-Contemporary-Folk-Album
# Sub-Genre URI: http://www.dei.unipd.it/~gdb/ontology/melody#Best-Hawaiian-Music-Album
# Sub-Genre URI: http://www.dei.unipd.it/~gdb/ontology/melody#Best-Native-American-Music-Album
# Sub-Genre URI: http://www.dei.unipd.it/~gdb/ontology/melody#Best-Zydeco-or-Cajun-Music-Album
# Macro Genre URI: http://www.dei.unipd.it/~gdb/ontology/melody#Childrens-Comedy-Audio-Books-Visual-Media-&-Music-Video/Film
# Sub-Genre URI: http://www.dei.unipd.it/~gdb/ontology/melody#Best-Childrens-Music-Album
# Sub-Genre URI: http://www.dei.unipd.it/~gdb/ontology/melody#Best-Comedy-Album
# Sub-Genre URI: http://www.dei.unipd.it/~gdb/ontology/melody#Best-Audio-Book-Narration-&-Storytelling-Recording
# Sub-Genre URI: http://www.dei.unipd.it/~gdb/ontology/melody#Best-Compilation-Soundtrack-for-Visual-Media
# Sub-Genre URI: http://www.dei.unipd.it/~gdb/ontology/melody#Best-Score-Soundtrack-Album-for-Visual-Media
# Sub-Genre URI: http://www.dei.unipd.it/~gdb/ontology/melody#Best-Score-Soundtrack-for-Video-Games-and-Other-Interactive-Media
# Sub-Genre URI: http://www.dei.unipd.it/~gdb/ontology/melody#Best-Song-Written-for-Visual-Media
# Sub-Genre URI: http://www.dei.unipd.it/~gdb/ontology/melody#Best-Music-Video
# Sub-Genre URI: http://www.dei.unipd.it/~gdb/ontology/melody#Best-Music-Film
# Sub-Genre URI: http://www.dei.unipd.it/~gdb/ontology/melody#Best-Musical-Album-for-Children
# Sub-Genre URI: http://www.dei.unipd.it/~gdb/ontology/melody#Best-Spoken-Word-Album-for-Children
# Sub-Genre URI: http://www.dei.unipd.it/~gdb/ontology/melody#Best-Album-for-Children
# Sub-Genre URI: http://www.dei.unipd.it/~gdb/ontology/melody#Best-Concept-Music-Video
# Sub-Genre URI: http://www.dei.unipd.it/~gdb/ontology/melody#Best-Performance-Music-Video
# Sub-Genre URI: http://www.dei.unipd.it/~gdb/ontology/melody#Video-of-the-Year
# Macro Genre URI: http://www.dei.unipd.it/~gdb/ontology/melody#Package-Notes-&-Historical
# Sub-Genre URI: http://www.dei.unipd.it/~gdb/ontology/melody#Best-Recording-Package
# Sub-Genre URI: http://www.dei.unipd.it/~gdb/ontology/melody#Best-Boxed-or-Special-Limited-Edition-Package
# Sub-Genre URI: http://www.dei.unipd.it/~gdb/ontology/melody#Best-Album-Notes
# Sub-Genre URI: http://www.dei.unipd.it/~gdb/ontology/melody#Best-Historical-Album
# Macro Genre URI: http://www.dei.unipd.it/~gdb/ontology/melody#Production-Engineering-Composition-&-Arrangement
# Sub-Genre URI: http://www.dei.unipd.it/~gdb/ontology/melody#Best-Engineered-Album-Non-Classical
# Sub-Genre URI: http://www.dei.unipd.it/~gdb/ontology/melody#Best-Engineered-Album-Classical
# Sub-Genre URI: http://www.dei.unipd.it/~gdb/ontology/melody#Producer-of-the-Year-Classical
# Sub-Genre URI: http://www.dei.unipd.it/~gdb/ontology/melody#Best-Immersive-Audio-Album
# Sub-Genre URI: http://www.dei.unipd.it/~gdb/ontology/melody#Best-Instrumental-Composition
# Sub-Genre URI: http://www.dei.unipd.it/~gdb/ontology/melody#Best-Arrangement-Instrumental-or-A-Cappella
# Sub-Genre URI: http://www.dei.unipd.it/~gdb/ontology/melody#Best-Arrangement-Instruments-and-Vocals
# Sub-Genre URI: http://www.dei.unipd.it/~gdb/ontology/melody#Best-Arrangement
# Sub-Genre URI: http://www.dei.unipd.it/~gdb/ontology/melody#Best-Vocal-Arrangement-for-Two-or-More-Voices
# Sub-Genre URI: http://www.dei.unipd.it/~gdb/ontology/melody#Best-Engineered-Recording--Special-or-Novel-Effects
# Macro Genre URI: http://www.dei.unipd.it/~gdb/ontology/melody#Classical
# Sub-Genre URI: http://www.dei.unipd.it/~gdb/ontology/melody#Best-Orchestral-Performance
# Sub-Genre URI: http://www.dei.unipd.it/~gdb/ontology/melody#Best-Opera-Recording
# Sub-Genre URI: http://www.dei.unipd.it/~gdb/ontology/melody#Best-Choral-Performance
# Sub-Genre URI: http://www.dei.unipd.it/~gdb/ontology/melody#Best-Chamber-Music/Small-Ensemble-Performance
# Sub-Genre URI: http://www.dei.unipd.it/~gdb/ontology/melody#Best-Classical-Instrumental-Solo
# Sub-Genre URI: http://www.dei.unipd.it/~gdb/ontology/melody#Best-Classical-Solo-Vocal-Album
# Sub-Genre URI: http://www.dei.unipd.it/~gdb/ontology/melody#Best-Classical-Compendium
# Sub-Genre URI: http://www.dei.unipd.it/~gdb/ontology/melody#Best-Contemporary-Classical-Composition
# Sub-Genre URI: http://www.dei.unipd.it/~gdb/ontology/melody#Best-Latin-Recording
# Sub-Genre URI: http://www.dei.unipd.it/~gdb/ontology/melody#Best-Latin-Pop-Rock-or-Urban-Album
# Sub-Genre URI: http://www.dei.unipd.it/~gdb/ontology/melody#Best-Banda-or-Norteno-Album
# Sub-Genre URI: http://www.dei.unipd.it/~gdb/ontology/melody#Best-Regional-Mexican-Album
# Sub-Genre URI: http://www.dei.unipd.it/~gdb/ontology/melody#Best-Mexican/Mexican-American-Album
# Sub-Genre URI: http://www.dei.unipd.it/~gdb/ontology/melody#Best-Banda-Album
# Sub-Genre URI: http://www.dei.unipd.it/~gdb/ontology/melody#Best-Norteno-Album
# Sub-Genre URI: http://www.dei.unipd.it/~gdb/ontology/melody#Best-Tejano-Album
# Sub-Genre URI: http://www.dei.unipd.it/~gdb/ontology/melody#Best-Latin-Urban-Album
# Sub-Genre URI: http://www.dei.unipd.it/~gdb/ontology/melody#Best-Merengue-Album
# Sub-Genre URI: http://www.dei.unipd.it/~gdb/ontology/melody#Best-Salsa-Album
# Sub-Genre URI: http://www.dei.unipd.it/~gdb/ontology/melody#Best-Salsa/Merengue-Album
# Sub-Genre URI: http://www.dei.unipd.it/~gdb/ontology/melody#Best-Instrumental-Soloist-Performance
# Sub-Genre URI: http://www.dei.unipd.it/~gdb/ontology/melody#Best-Instrumental-Soloist-Performance
# Sub-Genre URI: http://www.dei.unipd.it/~gdb/ontology/melody#Best-Classical-Performance-Operatic-or-Choral
# Sub-Genre URI: http://www.dei.unipd.it/~gdb/ontology/melody#Best-Classical-Performance--Instrumental-Soloist-or-Soloists
# Sub-Genre URI: http://www.dei.unipd.it/~gdb/ontology/melody#Best-New-Classical-Artist
# Sub-Genre URI: http://www.dei.unipd.it/~gdb/ontology/melody#Best-Chamber-Music-Performance
# Sub-Genre URI: http://www.dei.unipd.it/~gdb/ontology/melody#Best-Classical-Album
# Sub-Genre URI: http://www.dei.unipd.it/~gdb/ontology/melody#Best-Classical-Crossover-Album

# %%
g.serialize(destination="GrammyCategories.ttl", format="turtle")
print("Creato file Turtle globale: GrammyCategories.ttl")
# Out:
# Creato file Turtle globale: GrammyCategories.ttl
